# %% [markdown]
# ### multiline code

# %%
total=1+2+3 \
    +4
print(total)
# Out:
# 10

# %% [markdown]
# ### Input function

# %%
a=input("enter a number")
b=input("enter second number")
print(int(a)+int(b))
# Out:
# 11

# %%
# Print statement

print("my name is","Upendra Tripathi",end=" ")
# Out:
# my name is Upendra Tripathi

# %%
# formatted string
x=8.19
print(f'my cgpa is {x}')
# Out:
# my cgpa is 8.19

# %%
#complex number
z1=1+2j
z2=complex(3,4)
print(z1+z2)
# Out:
# (4+6j)
