# %% [markdown]
# ### Matplot lib

# %%
import matplotlib.pyplot as plt

x=[1,2,3,4]
y=[1,2,3,4]

plt.plot(x,y)
plt.show()

# %%
# linear regression
#correlation,covariance,anova,manova,goodfitness(r^2)=(Essr)=
